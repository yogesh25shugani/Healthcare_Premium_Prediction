# %% [markdown]
# #### Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# #### Load Excel into DataFrame

# %%
df = pd.read_excel("data/premiums_rest.xlsx")
rows, col = df.shape
print(f"Total number of rows are {rows} and columns are {col}")
# Out:
# Total number of rows are 29904 and columns are 13

# %%
df['Genetical_Risk'] = 0

# %%
df.describe()
# Out:
#                 Age  Number Of Dependants  Income_Lakhs  \
# count  29904.000000          29904.000000  29904.000000
# mean      43.396536              2.380116     23.362059
# std       13.411893              1.431140     24.737076
# min       26.000000             -3.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max      356.000000              5.000000    930.000000
#
#        Annual_Premium_Amount  Genetical_Risk
# count           29904.000000         29904.0
# mean            20893.036684             0.0
# std              6935.844219             0.0
# min              3625.000000             0.0
# 25%             15698.000000             0.0
# 50%             20489.000000             0.0
# 75%             26360.000000             0.0
# max             43471.000000             0.0

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Region', 'Marital_status', 'Number Of Dependants',
#        'BMI_Category', 'Smoking_Status', 'Employment_Status', 'Income_Level',
#        'Income_Lakhs', 'Medical History', 'Insurance_Plan',
#        'Annual_Premium_Amount', 'Genetical_Risk'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(" ","_")
df.columns
# Out:
# Index(['age', 'gender', 'region', 'marital_status', 'number_of_dependants',
#        'bmi_category', 'smoking_status', 'employment_status', 'income_level',
#        'income_lakhs', 'medical_history', 'insurance_plan',
#        'annual_premium_amount', 'genetical_risk'],
#       dtype='object')

# %% [markdown]
# #### Treating Null Values

# %%
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           9
# employment_status        1
# income_level             9
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# genetical_risk           0
# dtype: int64

# %%
df = df.dropna() 
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           0
# employment_status        0
# income_level             0
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# genetical_risk           0
# dtype: int64

# %% [markdown]
# #### Treating Duplicates Rows

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %% [markdown]
# #### Treating Outliers

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  29886.000000          29886.000000  29886.000000
# mean      43.396105              2.379910     23.364184
# std       13.412657              1.431201     24.740339
# min       26.000000             -3.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max      356.000000              5.000000    930.000000
#
#        annual_premium_amount  genetical_risk
# count           29886.000000         29886.0
# mean            20892.303821             0.0
# std              6936.813440             0.0
# min              3625.000000             0.0
# 25%             15697.250000             0.0
# 50%             20489.000000             0.0
# 75%             26360.000000             0.0
# max             43471.000000             0.0

# %%
df = df[df.age<=100]

# %%
df[df.number_of_dependants<0].shape
# Out:
# (50, 14)

# %%
df['number_of_dependants'] = df['number_of_dependants'].abs()
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  29828.000000          29828.000000  29828.000000
# mean      43.095380              2.387790     23.371530
# std       11.041991              1.420641     24.751262
# min       26.000000              0.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max       72.000000              5.000000    930.000000
#
#        annual_premium_amount  genetical_risk
# count           29828.000000         29828.0
# mean            20901.900563             0.0
# std              6928.457636             0.0
# min              6538.000000             0.0
# 25%             15706.000000             0.0
# 50%             20496.000000             0.0
# 75%             26361.000000             0.0
# max             43471.000000             0.0

# %% [markdown]
# #### Boxplot for Numeric Columns

# %%
numeric_col = df.select_dtypes(include='number').columns
n_cols = 2  # Number of plots per row
n_rows = math.ceil(len(numeric_col) / n_cols)

plt.figure(figsize=(5 * n_cols, 4 * n_rows))

for i, col in enumerate(numeric_col, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.boxplot(x=df[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Histogram for Income column

# %%
df['income_lakhs'].hist(bins=30, figsize=(6,4))
plt.title("Distribution of Income")
plt.xlabel("Income in Lakhs")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Outlier Removal using IQR

# %%
def iqr_cal(col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

# %%
upper, lower = iqr_cal('income_lakhs')
print(upper, lower)
# Out:
# -30.5 69.5

# %%
quantile_threshold = df.income_lakhs.quantile(0.999)
quantile_threshold
# Out:
# np.float64(100.0)

# %%
df = df[df['income_lakhs']<quantile_threshold]
df[df['income_lakhs']>100]
# Out:
# Empty DataFrame
# Columns: [age, gender, region, marital_status, number_of_dependants, bmi_category, smoking_status, employment_status, income_level, income_lakhs, medical_history, insurance_plan, annual_premium_amount, genetical_risk]
# Index: []

# %% [markdown]
# #### Histogram for Numeric Columns

# %%
df.hist(figsize=(12,8), bins=30)
plt.tight_layout()
plt.show()

# %%
# num_col = numeric_col
num_col = numeric_col.drop('annual_premium_amount')  # remove target

n_cols = 2
n_rows = math.ceil(len(num_col) / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(6*n_cols, 4*n_rows))
axes = axes.flatten()

for i, col in enumerate(num_col):
    sns.scatterplot(x=df[col], y=df['annual_premium_amount'], ax=axes[i])
    axes[i].set_title(f"{col} vs Premium Amount")

# Remove extra empty plots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Outlier Removal in Categorical Column

# %%
cat_col = df.select_dtypes(include='object').columns
cat_col
# Out:
# Index(['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status',
#        'employment_status', 'income_level', 'medical_history',
#        'insurance_plan'],
#       dtype='object')

# %%
for col in cat_col:
    print(f"{col}:{df[col].unique()}")
# Out:
# gender:['Male' 'Female']
# region:['Northwest' 'Southeast' 'Northeast' 'Southwest']
# marital_status:['Unmarried' 'Married']
# bmi_category:['Normal' 'Obesity' 'Overweight' 'Underweight']
# smoking_status:['No Smoking' 'Regular' 'Occasional' 'Does Not Smoke' 'Not Smoking'
#  'Smoking=0']
# employment_status:['Salaried' 'Self-Employed' 'Freelancer']
# income_level:['<10L' '10L - 25L' '> 40L' '25L - 40L']
# medical_history:['Diabetes' 'High blood pressure' 'No Disease'
#  'Diabetes & High blood pressure' 'Thyroid' 'Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid'
#  'Diabetes & Heart disease']
# insurance_plan:['Bronze' 'Silver' 'Gold']

# %%
df['smoking_status'] = df['smoking_status'].replace(
    ['Smoking=0', 'Does Not Smoke', 'Not Smoking'],
    'No Smoking')

# %%
for col in cat_col:
    print(f"{col}:{df[col].unique()}")
# Out:
# gender:['Male' 'Female']
# region:['Northwest' 'Southeast' 'Northeast' 'Southwest']
# marital_status:['Unmarried' 'Married']
# bmi_category:['Normal' 'Obesity' 'Overweight' 'Underweight']
# smoking_status:['No Smoking' 'Regular' 'Occasional']
# employment_status:['Salaried' 'Self-Employed' 'Freelancer']
# income_level:['<10L' '10L - 25L' '> 40L' '25L - 40L']
# medical_history:['Diabetes' 'High blood pressure' 'No Disease'
#  'Diabetes & High blood pressure' 'Thyroid' 'Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid'
#  'Diabetes & Heart disease']
# insurance_plan:['Bronze' 'Silver' 'Gold']

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      16334
# Female    13420
# Name: count, dtype: int64

# %%
n_cols = 2
n_rows = math.ceil(len(cat_col) / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(6*n_cols, 4*n_rows))
axes = axes.flatten()

for i, col in enumerate(cat_col):
    sns.countplot(x=df[col], ax=axes[i])
    axes[i].set_title(col)
    axes[i].tick_params(axis='x', rotation=45)

# Remove extra empty plots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Bi-Variate Analysis

# %%
pd.crosstab(df['income_level'], df['insurance_plan'])
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L          799  3554    4354
# 25L - 40L          301  2631    3142
# <10L              6054   527    4341
# > 40L              211  3231     609

# %% [markdown]
# #### Feature Engineering

# %%
df.medical_history.unique()
# Out:
# array(['Diabetes', 'High blood pressure', 'No Disease',
#        'Diabetes & High blood pressure', 'Thyroid', 'Heart disease',
#        'High blood pressure & Heart disease', 'Diabetes & Thyroid',
#        'Diabetes & Heart disease'], dtype=object)

# %%
risk_scores = {
    'diabetes':6,
    'heart disease':8,
    'high blood pressure':6,
    'no disease':0,
    'thyroid':5,
    'none':0
}

# %%
df[['disease1','disease2']] = df['medical_history'].str.split("&", expand=True).apply(lambda x:x.str.lower().str.strip())

# %%
df.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   56    Male  Northeast        Married                     3      Obesity
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4     Occasional     Self-Employed    10L - 25L            14
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk  \
# 0             Diabetes         Bronze                   9053               0
# 1             Diabetes         Bronze                  16339               0
# 2  High blood pressure         Silver                  18164               0
# 3           No Disease           Gold                  20303               0
# 4             Diabetes         Bronze                  15610               0
#
#               disease1 disease2
# 0             diabetes     None
# 1             diabetes     None
# 2  high blood pressure     None
# 3           no disease     None
# 4             diabetes     None

# %%
df['disease1'].fillna('none', inplace=True)
df['disease2'].fillna('none', inplace=True)
df.head()
invalid_rows = df[~df['disease1'].isin(risk_scores.keys())]
invalid_rows
# Out:
# C:\Users\yogesh\AppData\Local\Temp\ipykernel_15904\3574473948.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['disease1'].fillna('none', inplace=True)
# C:\Users\yogesh\AppData\Local\Temp\ipykernel_15904\3574473948.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['disease2'].fillna('none', inplace=True)
# Empty DataFrame
# Columns: [age, gender, region, marital_status, number_of_dependants, bmi_category, smoking_status, employment_status, income_level, income_lakhs, medical_history, insurance_plan, annual_premium_amount, genetical_risk, disease1, disease2]
# Index: []

# %%
df['total_risk_score'] = 0

for disease in ['disease1','disease2']:
    df['total_risk_score'] += df[disease].map(risk_scores)
max_score = df['total_risk_score'].max()
min_score = df['total_risk_score'].min()
df['normalized_risk_score'] = (df['total_risk_score'] - min_score )/(max_score - min_score)
df.sample(5)
# Out:
#        age  gender     region marital_status  number_of_dependants  \
# 12272   50  Female  Southwest        Married                     3
# 9310    43    Male  Northwest        Married                     2
# 5519    38  Female  Southeast        Married                     4
# 23007   29    Male  Southwest        Married                     3
# 8581    38  Female  Northwest      Unmarried                     0
#
#       bmi_category smoking_status employment_status income_level  \
# 12272   Overweight     No Smoking          Salaried        > 40L
# 9310        Normal     No Smoking          Salaried    10L - 25L
# 5519        Normal        Regular     Self-Employed    10L - 25L
# 23007       Normal     No Smoking          Salaried        > 40L
# 8581        Normal        Regular     Self-Employed    25L - 40L
#
#        income_lakhs      medical_history insurance_plan  \
# 12272            75             Diabetes         Silver
# 9310             11  High blood pressure         Silver
# 5519             13              Thyroid         Silver
# 23007            84             Diabetes         Silver
# 8581             35             Diabetes         Silver
#
#        annual_premium_amount  genetical_risk             disease1 disease2  \
# 12272                  20367               0             diabetes     none
# 9310                   15243               0  high blood pressure     none
# 5519                   18940               0              thyroid     none
# 23007                  15057               0             diabetes     none
# 8581                   18699               0             diabetes     none
#
#        total_risk_score  normalized_risk_score
# 12272                 6               0.428571
# 9310                  6               0.428571
# 5519                  5               0.357143
# 23007                 6               0.428571
# 8581                  6               0.428571

# %%
df.insurance_plan.unique()
# Out:
# array(['Bronze', 'Silver', 'Gold'], dtype=object)

# %%
df['insurance_plan'] = df['insurance_plan'].map({'Bronze':1, 'Silver':2, 'Gold':3})
df.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   56    Male  Northeast        Married                     3      Obesity
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4     Occasional     Self-Employed    10L - 25L            14
#
#        medical_history  insurance_plan  annual_premium_amount  genetical_risk  \
# 0             Diabetes               1                   9053               0
# 1             Diabetes               1                  16339               0
# 2  High blood pressure               2                  18164               0
# 3           No Disease               3                  20303               0
# 4             Diabetes               1                  15610               0
#
#               disease1 disease2  total_risk_score  normalized_risk_score
# 0             diabetes     none                 6               0.428571
# 1             diabetes     none                 6               0.428571
# 2  high blood pressure     none                 6               0.428571
# 3           no disease     none                 0               0.000000
# 4             diabetes     none                 6               0.428571

# %%
df.insurance_plan.unique()
# Out:
# array([1, 2, 3])

# %%
df['income_level'].unique()
# Out:
# array(['<10L', '10L - 25L', '> 40L', '25L - 40L'], dtype=object)

# %%
df['income_level'] = df['income_level'].map({'<10L':1, '10L - 25L':2, '> 40L':4, '25L - 40L':3})
df.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status  income_level  income_lakhs  \
# 0     No Smoking          Salaried             1             6
# 1        Regular          Salaried             1             6
#
#   medical_history  insurance_plan  annual_premium_amount  genetical_risk  \
# 0        Diabetes               1                   9053               0
# 1        Diabetes               1                  16339               0
#
#    disease1 disease2  total_risk_score  normalized_risk_score
# 0  diabetes     none                 6               0.428571
# 1  diabetes     none                 6               0.428571

# %%
df['income_level'].unique()
# Out:
# array([1, 2, 4, 3])

# %%
nominal_cols = ['gender','region','marital_status','bmi_category','smoking_status','employment_status']
df = pd.get_dummies(df, columns=nominal_cols, drop_first=True, dtype=int)
df.head()
# Out:
#    age  number_of_dependants  income_level  income_lakhs      medical_history  \
# 0   26                     0             1             6             Diabetes
# 1   29                     2             1             6             Diabetes
# 2   49                     2             2            20  High blood pressure
# 3   30                     3             4            77           No Disease
# 4   56                     3             2            14             Diabetes
#
#    insurance_plan  annual_premium_amount  genetical_risk             disease1  \
# 0               1                   9053               0             diabetes
# 1               1                  16339               0             diabetes
# 2               2                  18164               0  high blood pressure
# 3               3                  20303               0           no disease
# 4               1                  15610               0             diabetes
#
#   disease2  ...  region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0     none  ...                 0                 0                         1
# 1     none  ...                 1                 0                         0
# 2     none  ...                 0                 0                         0
# 3     none  ...                 1                 0                         0
# 4     none  ...                 0                 0                         0
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        0                         0
# 1                     1                        0                         0
# 2                     0                        0                         0
# 3                     0                        0                         0
# 4                     1                        0                         0
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 0                          0                       0
# 1                          0                       1
# 2                          0                       0
# 3                          0                       0
# 4                          1                       0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
# 3                           1                                0
# 4                           0                                1
#
# [5 rows x 24 columns]

# %%
df = df.drop(['medical_history','disease1','disease2','total_risk_score'],axis=1)

# %%
df.head(2)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   26                     0             1             6               1
# 1   29                     2             1             6               1
#
#    annual_premium_amount  genetical_risk  normalized_risk_score  gender_Male  \
# 0                   9053               0               0.428571            1
# 1                  16339               0               0.428571            0
#
#    region_Northwest  region_Southeast  region_Southwest  \
# 0                 1                 0                 0
# 1                 0                 1                 0
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 0                         1                     0                        0
# 1                         0                     1                        0
#
#    bmi_category_Underweight  smoking_status_Occasional  \
# 0                         0                          0
# 1                         0                          0
#
#    smoking_status_Regular  employment_status_Salaried  \
# 0                       0                           1
# 1                       1                           1
#
#    employment_status_Self-Employed
# 0                                0
# 1                                0

# %% [markdown]
# #### Correlation

# %%
cm = df.corr()

plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_level', 'income_lakhs',
#        'insurance_plan', 'annual_premium_amount', 'genetical_risk',
#        'normalized_risk_score', 'gender_Male', 'region_Northwest',
#        'region_Southeast', 'region_Southwest', 'marital_status_Unmarried',
#        'bmi_category_Obesity', 'bmi_category_Overweight',
#        'bmi_category_Underweight', 'smoking_status_Occasional',
#        'smoking_status_Regular', 'employment_status_Salaried',
#        'employment_status_Self-Employed'],
#       dtype='object')

# %%
X = df.drop('annual_premium_amount', axis=1)
y = df['annual_premium_amount']
cols_to_scale = ['age','income_level','income_lakhs','insurance_plan','number_of_dependants','genetical_risk']
scaler = MinMaxScaler()

X[cols_to_scale] = scaler.fit_transform(X[cols_to_scale])
X.head()
# Out:
#         age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0  0.000000                   0.0      0.000000      0.051020             0.0
# 1  0.065217                   0.4      0.000000      0.051020             0.0
# 2  0.500000                   0.4      0.333333      0.193878             0.5
# 3  0.086957                   0.6      1.000000      0.775510             1.0
# 4  0.652174                   0.6      0.333333      0.132653             0.0
#
#    genetical_risk  normalized_risk_score  gender_Male  region_Northwest  \
# 0             0.0               0.428571            1                 1
# 1             0.0               0.428571            0                 0
# 2             0.0               0.428571            0                 0
# 3             0.0               0.000000            0                 0
# 4             0.0               0.428571            1                 0
#
#    region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0                 0                 0                         1
# 1                 1                 0                         0
# 2                 0                 0                         0
# 3                 1                 0                         0
# 4                 0                 0                         0
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        0                         0
# 1                     1                        0                         0
# 2                     0                        0                         0
# 3                     0                        0                         0
# 4                     1                        0                         0
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 0                          0                       0
# 1                          0                       1
# 2                          0                       0
# 3                          0                       0
# 4                          1                       0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
# 3                           1                                0
# 4                           0                                1

# %%
X.describe()
# Out:
#                 age  number_of_dependants  income_level  income_lakhs  \
# count  29754.000000          29754.000000  29754.000000  29754.000000
# mean       0.371683              0.477536      0.369788      0.225009
# std        0.240080              0.284145      0.350221      0.226314
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.173913              0.200000      0.000000      0.061224
# 50%        0.347826              0.600000      0.333333      0.163265
# 75%        0.565217              0.600000      0.666667      0.316327
# max        1.000000              1.000000      1.000000      1.000000
#
#        insurance_plan  genetical_risk  normalized_risk_score   gender_Male  \
# count    29754.000000         29754.0           29754.000000  29754.000000
# mean         0.543322             0.0               0.426404      0.548968
# std          0.378885             0.0               0.240132      0.497605
# min          0.000000             0.0               0.000000      0.000000
# 25%          0.500000             0.0               0.357143      0.000000
# 50%          0.500000             0.0               0.428571      1.000000
# 75%          1.000000             0.0               0.428571      1.000000
# max          1.000000             0.0               1.000000      1.000000
#
#        region_Northwest  region_Southeast  region_Southwest  \
# count      29754.000000      29754.000000      29754.000000
# mean           0.200746          0.352726          0.301875
# std            0.400565          0.477826          0.459079
# min            0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000
# 75%            0.000000          1.000000          1.000000
# max            1.000000          1.000000          1.000000
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# count              29754.000000          29754.000000
# mean                   0.253378              0.196982
# std                    0.434953              0.397725
# min                    0.000000              0.000000
# 25%                    0.000000              0.000000
# 50%                    0.000000              0.000000
# 75%                    1.000000              0.000000
# max                    1.000000              1.000000
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# count             29754.000000              29754.000000
# mean                  0.294918                  0.110103
# std                   0.456014                  0.313023
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   1.000000                  0.000000
# max                   1.000000                  1.000000
#
#        smoking_status_Occasional  smoking_status_Regular  \
# count               29754.000000            29754.000000
# mean                    0.173254                0.374605
# std                     0.378473                0.484029
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                1.000000
# max                     1.000000                1.000000
#
#        employment_status_Salaried  employment_status_Self-Employed
# count                29754.000000                     29754.000000
# mean                     0.466189                         0.354272
# std                      0.498864                         0.478300
# min                      0.000000                         0.000000
# 25%                      0.000000                         0.000000
# 50%                      0.000000                         0.000000
# 75%                      1.000000                         1.000000
# max                      1.000000                         1.000000

# %% [markdown]
# #### Calculating VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
# C:\Users\yogesh\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\regression\linear_model.py:1784: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
#                              Column        VIF
# 0                               age   3.924740
# 1              number_of_dependants   6.276728
# 2                      income_level  14.063416
# 3                      income_lakhs  11.408527
# 4                    insurance_plan   5.260860
# 5                    genetical_risk        NaN
# 6             normalized_risk_score   3.809601
# 7                       gender_Male   2.598259
# 8                  region_Northwest   2.123193
# 9                  region_Southeast   2.979784
# 10                 region_Southwest   2.708419
# 11         marital_status_Unmarried   2.345592
# 12             bmi_category_Obesity   1.478627
# 13          bmi_category_Overweight   1.734641
# 14         bmi_category_Underweight   1.255626
# 15        smoking_status_Occasional   1.378472
# 16           smoking_status_Regular   2.131700
# 17       employment_status_Salaried   3.178830
# 18  employment_status_Self-Employed   2.872173

# %%
calculate_vif(X.drop('income_level',axis=1))
# Out:
# C:\Users\yogesh\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\regression\linear_model.py:1784: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
#                              Column       VIF
# 0                               age  3.865086
# 1              number_of_dependants  6.276116
# 2                      income_lakhs  2.690925
# 3                    insurance_plan  4.571804
# 4                    genetical_risk       NaN
# 5             normalized_risk_score  3.807473
# 6                       gender_Male  2.590560
# 7                  region_Northwest  2.122529
# 8                  region_Southeast  2.978859
# 9                  region_Southwest  2.706927
# 10         marital_status_Unmarried  2.345161
# 11             bmi_category_Obesity  1.478241
# 12          bmi_category_Overweight  1.734212
# 13         bmi_category_Underweight  1.255305
# 14        smoking_status_Occasional  1.378451
# 15           smoking_status_Regular  2.131480
# 16       employment_status_Salaried  3.170319
# 17  employment_status_Self-Employed  2.867456

# %%
X_reduced = X.drop('income_level',axis=1)
X_reduced.head()
# Out:
#         age  number_of_dependants  income_lakhs  insurance_plan  \
# 0  0.000000                   0.0      0.051020             0.0
# 1  0.065217                   0.4      0.051020             0.0
# 2  0.500000                   0.4      0.193878             0.5
# 3  0.086957                   0.6      0.775510             1.0
# 4  0.652174                   0.6      0.132653             0.0
#
#    genetical_risk  normalized_risk_score  gender_Male  region_Northwest  \
# 0             0.0               0.428571            1                 1
# 1             0.0               0.428571            0                 0
# 2             0.0               0.428571            0                 0
# 3             0.0               0.000000            0                 0
# 4             0.0               0.428571            1                 0
#
#    region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0                 0                 0                         1
# 1                 1                 0                         0
# 2                 0                 0                         0
# 3                 1                 0                         0
# 4                 0                 0                         0
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        0                         0
# 1                     1                        0                         0
# 2                     0                        0                         0
# 3                     0                        0                         0
# 4                     1                        0                         0
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 0                          0                       0
# 1                          0                       1
# 2                          0                       0
# 3                          0                       0
# 4                          1                       0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
# 3                           1                                0
# 4                           0                                1

# %% [markdown]
# #### Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.3, random_state=10)

print("X train: ",X_train.shape)
print("X test: ",X_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# X train:  (20827, 18)
# X test:  (8927, 18)
# y train:  (20827,)
# y test:  (8927,)

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
r2_train = model_lr.score(X_train, y_train)
# y_pred = model_lr.predict(X_test)
r2_test = model_lr.score(X_test, y_test)

r2_test, r2_train
# Out:
# (0.9529823324689619, 0.9537747062669479)

# %%
model_lr.intercept_
# Out:
# np.float64(5934.16482285315)

# %%
model_lr.coef_
# Out:
# array([ 6.96353453e+03, -1.31279216e+03, -7.52016885e+02,  1.48577428e+04,
#         3.63797881e-12,  6.02525138e+03,  5.29109471e+01, -4.19355491e+01,
#        -4.28778476e+00, -5.58970719e+00, -7.20469122e+02,  3.95823598e+03,
#         2.01694333e+03,  6.05139302e+02,  8.29393700e+02,  2.80100338e+03,
#        -8.17751554e+01,  2.46364123e+02])

# %%
feature_importances = model_lr.coef_
coef_df = pd.DataFrame(feature_importances, index=X_test.columns, columns=['Coefficients'])
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

plt.figure(figsize=(8,4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficients Values')
plt.ylabel('Feature Importances')
plt.show()

# %%
model_rg = Ridge()
model_rg.fit(X_train, y_train)
r2_train = model_rg.score(X_train, y_train)
# y_pred = model_rg.predict(X_test)
r2_test = model_rg.score(X_test, y_test)

r2_test, r2_train
# Out:
# (0.9529834791901383, 0.9537745356368772)

# %%
from xgboost import XGBRegressor

# %%
model_xgb = XGBRegressor()
model_xgb.fit(X_train, y_train)
r2_train = model_xgb.score(X_train, y_train)
y_pred = model_xgb.predict(X_test)
r2_test = model_xgb.score(X_test, y_test)

r2_test, r2_train
# Out:
# (0.9980076551437378, 0.9986194968223572)

# %%
mse_xgb = mean_squared_error(y_test, y_pred)
rmse_xgb = np.sqrt(mse_xgb)
print(f"XGBoost Regression ==> MSE: {mse_xgb} RMSE: {rmse_xgb}")
# Out:
# XGBoost Regression ==> MSE: 96006.8515625 RMSE: 309.8497241607615

# %%
model_xgb = XGBRegressor()
param_grid = {
    'n_estimators': [20,40,50],
    'learning_rate': [0.01,0.1,0.2],
    'max_depth':[3,4,5]
}
random_search = RandomizedSearchCV(model_xgb, param_grid, n_iter=10, cv=3, scoring='r2')
random_search.fit(X_train, y_train)
random_search.best_score_
# Out:
# np.float64(0.997016191482544)

# %%
best_model = random_search.best_estimator_

# %%
feature_importances = best_model.feature_importances_
coef_df = pd.DataFrame(feature_importances, index=X_test.columns, columns=['Coefficients'])
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

plt.figure(figsize=(8,4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficients Values')
plt.ylabel('Feature Importances')
plt.show()

# %% [markdown]
# #### Error Analysis

# %%
y_pred = best_model.predict(X_test)

residuals = y_pred - y_test
residuals_pct = residuals*100/y_test
results_df = pd.DataFrame({
    'actual':y_test,
    'predicted':y_pred,
    'diff':residuals,
    'diff_pct':residuals_pct
})
results_df.head()
# Out:
#        actual     predicted        diff  diff_pct
# 18272   12370  12079.240234 -290.759766 -2.350524
# 24662   11253  11753.384766  500.384766  4.446679
# 1789    30688  30553.044922 -134.955078 -0.439765
# 29834   22139  22513.017578  374.017578  1.689406
# 1478    27040  27357.199219  317.199219  1.173074

# %%
sns.histplot(results_df['diff_pct'],kde=True)
plt.show()

# %%
extreme_error_threshold = 10
extreme_results_df = results_df[np.abs(results_df.diff_pct)>extreme_error_threshold]
extreme_results_df.shape
# Out:
# (32, 4)

# %%
extreme_error_pct = extreme_results_df.shape[0]*100/results_df.shape[0]
extreme_error_pct
# Out:
# 0.35846308950375266

# %%
results_df[np.abs(results_df.diff_pct)>10].sort_values('diff_pct', ascending=False)
# Out:
#        actual     predicted         diff   diff_pct
# 7547     6538   7649.378418  1111.378418  16.998752
# 15413    6625   7649.378418  1024.378418  15.462316
# 8506     6640   7649.378418  1009.378418  15.201482
# 29258    6673   7649.378418   976.378418  14.631776
# 8176     6676   7649.378418   973.378418  14.580264
# 13744    6691   7649.378418   958.378418  14.323396
# 7028     6706   7649.378418   943.378418  14.067677
# 10741    6706   7649.378418   943.378418  14.067677
# 3979     6711   7649.378418   938.378418  13.982691
# 11231    6760   7649.378418   889.378418  13.156485
# 14728    6788   7649.378418   861.378418  12.689723
# 4557     8145   9105.366211   960.366211  11.790868
# 1648     6843   7649.378418   806.378418  11.783990
# 6163     6847   7649.378418   802.378418  11.718686
# 25617    7574   8443.935547   869.935547  11.485814
# 9285     6872   7649.378418   777.378418  11.312259
# 13973   10583  11753.384766  1170.384766  11.059102
# 8835     6892   7649.378418   757.378418  10.989240
# 13903   10606  11753.384766  1147.384766  10.818261
# 6661     6904   7649.378418   745.378418  10.796327
# 24145    7627   8443.935547   816.935547  10.711099
# 2582     8507   9413.350586   906.350586  10.654174
# 252      7633   8443.935547   810.935547  10.624074
# 14521    6916   7649.378418   733.378418  10.604084
# 9150     6920   7649.378418   729.378418  10.540151
# 15581   10636  11753.384766  1117.384766  10.505686
# 9756     6929   7649.378418   720.378418  10.396571
# 22941    6934   7649.378418   715.378418  10.316966
# 1549     8543   9413.350586   870.350586  10.187880
# 29165    8547   9413.350586   866.350586  10.136312
# 23883    6947   7649.378418   702.378418  10.110529
# 29657    8554   9413.350586   859.350586  10.046184

# %%
from joblib import dump
dump(best_model,"../artifacts/model_rest.pkl")
scaler_with_cols = {
    'scaler':scaler,
    'cols_to_scale':cols_to_scale
}
dump(scaler_with_cols,"../artifacts/scaler_rest.pkl")
# Out:
# ['../artifacts/scaler_rest.pkl']
